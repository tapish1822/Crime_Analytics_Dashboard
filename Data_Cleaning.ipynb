# %%
import pandas as pd

# Try reading the CSV file with different encodings
try:
    df = pd.read_csv("/content/homicide-data.csv", encoding='utf-8')
except UnicodeDecodeError:
    # If utf-8 fails, try alternative encodings
    try:
        df = pd.read_csv("/content/homicide-data.csv", encoding='ISO-8859-1')
    except UnicodeDecodeError:
        # If ISO-8859-1 also fails, try another encoding such as 'Windows-1252'
        df = pd.read_csv("/content/homicide-data.csv", encoding='Windows-1252')

# Now you can continue working with the DataFrame 'df'

# %%
df.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race victim_age  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic         78
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic         17
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White         15
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic         32
# 4  Alb-000005       20100102         MULA       VIVIAN       White         72
#
#   victim_sex         city state        lat         lon            disposition
# 0       Male  Albuquerque    NM  35.095788 -106.538555  Closed without arrest
# 1       Male  Albuquerque    NM  35.056810 -106.715321       Closed by arrest
# 2     Female  Albuquerque    NM  35.086092 -106.695568  Closed without arrest
# 3       Male  Albuquerque    NM  35.078493 -106.556094       Closed by arrest
# 4     Female  Albuquerque    NM  35.130357 -106.580986  Closed without arrest

# %%
df['victim_age'] = pd.to_numeric(df['victim_age'], errors='coerce')

# %%
def age_to_slab(age):
    if age <= 20:
        return "0-20"
    elif age <= 30:
        return "21-30"
    elif age <= 40:
        return "31-40"
    elif age <= 50:
        return "41-50"
    elif age <= 60:
        return "51-60"
    elif age <= 70:
        return "61-70"
    elif age <= 80:
        return "71-80"
    elif age <= 90:
        return "81-90"
    elif age <= 100:
        return "91-100"
    elif age <= 110:
        return "101-110"
    else:
        return "Unknown"

# %%
df['age_slab'] = df['victim_age'].apply(age_to_slab)

# %%
df.head()
# Out:
#           uid  reported_date  victim_last victim_first victim_race  \
# 0  Alb-000001       20100504       GARCIA         JUAN    Hispanic
# 1  Alb-000002       20100216      MONTOYA      CAMERON    Hispanic
# 2  Alb-000003       20100601  SATTERFIELD      VIVIANA       White
# 3  Alb-000004       20100101     MENDIOLA       CARLOS    Hispanic
# 4  Alb-000005       20100102         MULA       VIVIAN       White
#
#    victim_age victim_sex         city state        lat         lon  \
# 0        78.0       Male  Albuquerque    NM  35.095788 -106.538555
# 1        17.0       Male  Albuquerque    NM  35.056810 -106.715321
# 2        15.0     Female  Albuquerque    NM  35.086092 -106.695568
# 3        32.0       Male  Albuquerque    NM  35.078493 -106.556094
# 4        72.0     Female  Albuquerque    NM  35.130357 -106.580986
#
#              disposition age_slab
# 0  Closed without arrest    71-80
# 1       Closed by arrest     0-20
# 2  Closed without arrest     0-20
# 3       Closed by arrest    31-40
# 4  Closed without arrest    71-80

# %%
df = df.drop(columns=['reported_date',	'victim_last',	'victim_first'], axis = 1)

# %%
df.head()
# Out:
#           uid victim_race  victim_age victim_sex         city state  \
# 0  Alb-000001    Hispanic        78.0       Male  Albuquerque    NM
# 1  Alb-000002    Hispanic        17.0       Male  Albuquerque    NM
# 2  Alb-000003       White        15.0     Female  Albuquerque    NM
# 3  Alb-000004    Hispanic        32.0       Male  Albuquerque    NM
# 4  Alb-000005       White        72.0     Female  Albuquerque    NM
#
#          lat         lon            disposition age_slab
# 0  35.095788 -106.538555  Closed without arrest    71-80
# 1  35.056810 -106.715321       Closed by arrest     0-20
# 2  35.086092 -106.695568  Closed without arrest     0-20
# 3  35.078493 -106.556094       Closed by arrest    31-40
# 4  35.130357 -106.580986  Closed without arrest    71-80

# %%
df.isnull().sum()
# Out:
# uid               0
# victim_race       0
# victim_age     2999
# victim_sex        0
# city              0
# state             0
# lat              60
# lon              60
# disposition       0
# age_slab          0
# dtype: int64

# %%
df['victim_race'].unique()
# Out:
# array(['Hispanic', 'White', 'Other', 'Black', 'Asian', 'Unknown'],
#       dtype=object)

# %%
df['victim_sex'].unique()
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Albuquerque', 'Atlanta', 'Baltimore', 'Baton Rouge', 'Birmingham',
#        'Boston', 'Buffalo', 'Charlotte', 'Chicago', 'Cincinnati',
#        'Columbus', 'Dallas', 'Denver', 'Detroit', 'Durham', 'Fort Worth',
#        'Fresno', 'Houston', 'Indianapolis', 'Jacksonville', 'Kansas City',
#        'Las Vegas', 'Long Beach', 'Los Angeles', 'Louisville', 'Memphis',
#        'Miami', 'Milwaukee', 'Minneapolis', 'Nashville', 'New Orleans',
#        'New York', 'Oakland', 'Oklahoma City', 'Omaha', 'Philadelphia',
#        'Phoenix', 'Pittsburgh', 'Richmond', 'San Antonio', 'Sacramento',
#        'Savannah', 'San Bernardino', 'San Diego', 'San Francisco',
#        'St. Louis', 'Stockton', 'Tampa', 'Tulsa', 'Washington'],
#       dtype=object)

# %%
df['state'].unique()
# Out:
# array(['NM', 'GA', 'MD', 'LA', 'AL', 'MA', 'NY', 'NC', 'IL', 'OH', 'TX',
#        'CO', 'MI', 'CA', 'IN', 'FL', 'MO', 'NV', 'KY', 'TN', 'wI', 'MN',
#        'OK', 'NE', 'PA', 'AZ', 'VA', 'DC'], dtype=object)

# %%
df = df.drop(columns=['victim_age'], axis = 1)

# %%
df['disposition'].unique()
# Out:
# array(['Closed without arrest', 'Closed by arrest', 'Open/No arrest'],
#       dtype=object)

# %%
df.head()
# Out:
#           uid victim_race victim_sex         city state        lat  \
# 0  Alb-000001    Hispanic       Male  Albuquerque    NM  35.095788
# 1  Alb-000002    Hispanic       Male  Albuquerque    NM  35.056810
# 2  Alb-000003       White     Female  Albuquerque    NM  35.086092
# 3  Alb-000004    Hispanic       Male  Albuquerque    NM  35.078493
# 4  Alb-000005       White     Female  Albuquerque    NM  35.130357
#
#           lon            disposition age_slab
# 0 -106.538555  Closed without arrest    71-80
# 1 -106.715321       Closed by arrest     0-20
# 2 -106.695568  Closed without arrest     0-20
# 3 -106.556094       Closed by arrest    31-40
# 4 -106.580986  Closed without arrest    71-80

# %%
df.to_csv('distinct_victim_races.csv', index=False)
